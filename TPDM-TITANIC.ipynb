# %%
import os
os.chdir("D:\DM")

# %%
import pandas as pd

# %%
dfT = pd.read_excel('titanic3.xls', header=0)

# %%
dfT.info()
#Afficher les données de la dataset Titanic
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
dfT.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
dfT
#Afficher les données de la dataset Titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
#Afficher des caractéristiques / variables
dfT.columns
dfT.index
dfT
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
#Dimension de la dataset
dfT.shape
# Out:
# (1309, 14)

# %%
#Sélection des lignes et des colonnes
dfT.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
#Sélection des lignes et des colonnes
dfT.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
#Sélection des lignes et des colonnes
dfT.sex
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
#Sélection des lignes et des colonnes
dfT.loc[:1000,['name', 'sex']]
# Out:
#                                                  name     sex
# 0                       Allen, Miss. Elisabeth Walton  female
# 1                      Allison, Master. Hudson Trevor    male
# 2                        Allison, Miss. Helen Loraine  female
# 3                Allison, Mr. Hudson Joshua Creighton    male
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...                                               ...     ...
# 996                                Markun, Mr. Johann    male
# 997                           Masselmani, Mrs. Fatima  female
# 998                              Matinoff, Mr. Nicola    male
# 999                 McCarthy, Miss. Catherine "Katie"  female
# 1000                     McCormack, Mr. Thomas Joseph    male
#
# [1001 rows x 2 columns]

# %%
dfT.iloc[:5,[0,3]]
# Out:
#    pclass     sex
# 0       1  female
# 1       1    male
# 2       1  female
# 3       1    male
# 4       1  female

# %%
dfT.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
#Obtenir les valeurs 
dfT['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
pd.get_dummies('sex')
# Out:
#    sex
# 0    1

# %%
dfT.groupby(by=['sex']).count()
# Out:
#         pclass  survived  name  age  sibsp  parch  ticket  fare  cabin  \
# sex
# female     466       466   466  388    466    466     466   466    141
# male       843       843   843  658    843    843     843   842    154
#
#         embarked  boat  body  home.dest
# sex
# female       464   319     8        288
# male         843   167   113        457

# %%
#Obtenir les valeurs 
dfT['embarked'].unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
dfT['embarked']=dfT['embarked'].replace('S',13)
dfT['embarked']=dfT['embarked'].replace('C',33)
dfT['embarked']=dfT['embarked'].replace('Q',56)

# %%
dfT['embarked'].unique()
# Out:
# array([13., 33., nan, 56.])

# %%
#supprimer nan
dfT['embarked'].dropna(inplace=True)

# %%
dfT['embarked'].unique()
# Out:
# array([13., 33., nan, 56.])

# %%
dfT.groupby(by=['embarked']).count()
# Out:
#           pclass  survived  name  sex  age  sibsp  parch  ticket  fare  cabin  \
# embarked
# 13.0         914       914   914  914  782    914    914     914   913    170
# 33.0         270       270   270  270  212    270    270     270   270    118
# 56.0         123       123   123  123   50    123    123     123   123      5
#
#           boat  body  home.dest
# embarked
# 13.0       297    89        535
# 33.0       149    25        172
# 56.0        38     7         37

# %%
from sklearn.preprocessing import LabelEncoder
dfT['sex']= LabelEncoder().fit_transform(dfT['sex'].astype(str))
dfT['embarked']= LabelEncoder().fit_transform(dfT['embarked'].astype(str))

# %%
dfT
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    0
# 1          1         1                   Allison, Master. Hudson Trevor    1
# 2          1         0                     Allison, Miss. Helen Loraine    0
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    1
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    0
# 1305       3         0                            Zabour, Miss. Thamine    0
# 1306       3         0                        Zakarian, Mr. Mapriededer    1
# 1307       3         0                              Zakarian, Mr. Ortin    1
# 1308       3         0                               Zimmerman, Mr. Leo    1
#
# ...

# %%
dfT['sex'].unique()
# Out:
# array([0, 1])

# %%
#isna() function is used to detect missing values
dfT.isna().describe()
# Out:
#        pclass survived   name    sex    age  sibsp  parch ticket   fare cabin  \
# count    1309     1309   1309   1309   1309   1309   1309   1309   1309  1309
# unique      1        1      1      1      2      1      1      1      2     2
# top     False    False  False  False  False  False  False  False  False  True
# freq     1309     1309   1309   1309   1046   1309   1309   1309   1308  1014
#
#        embarked  boat  body home.dest
# count      1309  1309  1309      1309
# unique        1     2     2         2
# top       False  True  True     False
# freq       1309   823  1188       745

# %%
dfT['cabin'].fillna(method='bfill', inplace=True)
dfT['body'].isna().describe()
# Out:
# count     1309
# unique       2
# top       True
# freq      1188
# Name: body, dtype: object

# %%
 #to Calculate Mean or Average in Python 
mean_age = dfT['age'].mean()
mean_age
# Out:
# 29.8811345124283

# %%
dfT['sex'].value_counts()
# Out:
# 1    843
# 0    466
# Name: sex, dtype: int64

# %%
dfT['embarked'].value_counts()
# Out:
# 0    914
# 1    270
# 2    123
# 3      2
# Name: embarked, dtype: int64

# %%
#si la valeur est NaN, la fonction retourne True
dfT.isnull()
# Out:
#       pclass  survived   name    sex    age  sibsp  parch  ticket   fare  \
# 0      False     False  False  False  False  False  False   False  False
# 1      False     False  False  False  False  False  False   False  False
# 2      False     False  False  False  False  False  False   False  False
# 3      False     False  False  False  False  False  False   False  False
# 4      False     False  False  False  False  False  False   False  False
# ...      ...       ...    ...    ...    ...    ...    ...     ...    ...
# 1304   False     False  False  False  False  False  False   False  False
# 1305   False     False  False  False   True  False  False   False  False
# 1306   False     False  False  False  False  False  False   False  False
# 1307   False     False  False  False  False  False  False   False  False
# 1308   False     False  False  False  False  False  False   False  False
#
#       cabin  embarked   boat   body  home.dest
# ...

# %%
 # si la valeur est différente de NaN, la fonction retourne True
dfT.notnull()
# Out:
#       pclass  survived  name   sex    age  sibsp  parch  ticket  fare  cabin  \
# 0       True      True  True  True   True   True   True    True  True   True
# 1       True      True  True  True   True   True   True    True  True   True
# 2       True      True  True  True   True   True   True    True  True   True
# 3       True      True  True  True   True   True   True    True  True   True
# 4       True      True  True  True   True   True   True    True  True   True
# ...      ...       ...   ...   ...    ...    ...    ...     ...   ...    ...
# 1304    True      True  True  True   True   True   True    True  True  False
# 1305    True      True  True  True  False   True   True    True  True  False
# 1306    True      True  True  True   True   True   True    True  True  False
# 1307    True      True  True  True   True   True   True    True  True  False
# 1308    True      True  True  True   True   True   True    True  True  False
#
#       embarked   boat   body  home.dest
# ...

# %%
#remplacer les valeurs manquantes avec les valeurs précédentes ou par celles qui suivent
dfT['sex'].fillna(method='pad')
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    1
# 1307    1
# 1308    1
# Name: sex, Length: 1309, dtype: int32

# %%
dfT['body'].fillna(method='pad')
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3       135.0
# 4       135.0
#         ...
# 1304    328.0
# 1305    328.0
# 1306    304.0
# 1307    304.0
# 1308    304.0
# Name: body, Length: 1309, dtype: float64

# %%
dfT['body'].fillna(method='bfill')
# Out:
# 0       135.0
# 1       135.0
# 2       135.0
# 3       135.0
# 4        22.0
#         ...
# 1304    328.0
# 1305    304.0
# 1306    304.0
# 1307      NaN
# 1308      NaN
# Name: body, Length: 1309, dtype: float64

# %%
dfT
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    0
# 1          1         1                   Allison, Master. Hudson Trevor    1
# 2          1         0                     Allison, Miss. Helen Loraine    0
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    1
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    0
# 1305       3         0                            Zabour, Miss. Thamine    0
# 1306       3         0                        Zakarian, Mr. Mapriededer    1
# 1307       3         0                              Zakarian, Mr. Ortin    1
# 1308       3         0                               Zimmerman, Mr. Leo    1
#
# ...

# %%
dfT['cabin'].fillna(method='bfill')
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304        NaN
# 1305        NaN
# 1306        NaN
# 1307        NaN
# 1308        NaN
# Name: cabin, Length: 1309, dtype: object

# %%
#remplacer les valeurs manquantes de l’age .
dfT['age'].fillna(30.0111, inplace=True)
dfT.age
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305    30.0111
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
dfT['boat'].fillna(30.0111, inplace=True)
dfT.boat
# Out:
# 0             2
# 1            11
# 2       30.0111
# 3       30.0111
# 4       30.0111
#          ...
# 1304    30.0111
# 1305    30.0111
# 1306    30.0111
# 1307    30.0111
# 1308    30.0111
# Name: boat, Length: 1309, dtype: object

# %%
dfT['body'].fillna(177, inplace=True)
dfT.body
# Out:
# 0       177.0
# 1       177.0
# 2       177.0
# 3       135.0
# 4       177.0
#         ...
# 1304    328.0
# 1305    177.0
# 1306    304.0
# 1307    177.0
# 1308    177.0
# Name: body, Length: 1309, dtype: float64

# %%
#supprimer les colonnes qui contiennent au moins une valeur manquante
dfT.dropna(axis=1, how='any')
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    0
# 1          1         1                   Allison, Master. Hudson Trevor    1
# 2          1         0                     Allison, Miss. Helen Loraine    0
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    1
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    0
# 1305       3         0                            Zabour, Miss. Thamine    0
# 1306       3         0                        Zakarian, Mr. Mapriededer    1
# 1307       3         0                              Zakarian, Mr. Ortin    1
# 1308       3         0                               Zimmerman, Mr. Leo    1
#
# ...

# %%
dfT['boat'].dropna()
# Out:
# 0             2
# 1            11
# 2       30.0111
# 3       30.0111
# 4       30.0111
#          ...
# 1304    30.0111
# 1305    30.0111
# 1306    30.0111
# 1307    30.0111
# 1308    30.0111
# Name: boat, Length: 1309, dtype: object

# %%
dfT['boat'].drop
# Out:
# <bound method Series.drop of 0             2
# 1            11
# 2       30.0111
# 3       30.0111
# 4       30.0111
#          ...
# 1304    30.0111
# 1305    30.0111
# 1306    30.0111
# 1307    30.0111
# 1308    30.0111
# Name: boat, Length: 1309, dtype: object>

# %%
dfT['boat'].pop
# Out:
# <bound method Series.pop of 0             2
# 1            11
# 2       30.0111
# 3       30.0111
# 4       30.0111
#          ...
# 1304    30.0111
# 1305    30.0111
# 1306    30.0111
# 1307    30.0111
# 1308    30.0111
# Name: boat, Length: 1309, dtype: object>

# %%
dfT
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    0
# 1          1         1                   Allison, Master. Hudson Trevor    1
# 2          1         0                     Allison, Miss. Helen Loraine    0
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    1
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    0
# 1305       3         0                            Zabour, Miss. Thamine    0
# 1306       3         0                        Zakarian, Mr. Mapriededer    1
# 1307       3         0                              Zakarian, Mr. Ortin    1
# 1308       3         0                               Zimmerman, Mr. Leo    1
#
# ...

# %%
dfT.drop(['boat','ticket','name','home.dest'], axis=1, inplace=True)

# %%
dfT
# Out:
#       pclass  survived  sex      age  sibsp  parch      fare    cabin  \
# 0          1         1    0  29.0000      0      0  211.3375       B5
# 1          1         1    1   0.9167      1      2  151.5500  C22 C26
# 2          1         0    0   2.0000      1      2  151.5500  C22 C26
# 3          1         0    1  30.0000      1      2  151.5500  C22 C26
# 4          1         0    0  25.0000      1      2  151.5500  C22 C26
# ...      ...       ...  ...      ...    ...    ...       ...      ...
# 1304       3         0    0  14.5000      1      0   14.4542      NaN
# 1305       3         0    0  30.0111      1      0   14.4542      NaN
# 1306       3         0    1  26.5000      0      0    7.2250      NaN
# 1307       3         0    1  27.0000      0      0    7.2250      NaN
# 1308       3         0    1  29.0000      0      0    7.8750      NaN
#
#       embarked   body
# 0            0  177.0
# 1            0  177.0
# 2            0  177.0
# 3            0  135.0
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler_data = scaler.fit_transform(dfT[['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch','fare', 'embarked']])
scaler_data
# Out:
# array([[-1.54609786,  1.27200629, -1.34499549, ..., -0.4449995 ,
#          3.44116502, -0.60334283],
#        [-1.54609786,  1.27200629,  0.74349692, ...,  1.86652569,
#          2.28560268, -0.60334283],
#        [-1.54609786, -0.78615963, -1.34499549, ...,  1.86652569,
#          2.28560268, -0.60334283],
#        ...,
#        [ 0.84191642, -0.78615963,  0.74349692, ..., -0.4449995 ,
#         -0.50388566,  0.90963756],
#        [ 0.84191642, -0.78615963,  0.74349692, ..., -0.4449995 ,
#         -0.50388566,  0.90963756],
#        [ 0.84191642, -0.78615963,  0.74349692, ..., -0.4449995 ,
#         -0.49132258, -0.60334283]])

# %%
L=LabelEncoder()
label=L.fit_transform(dfT['fare'])
Data=dfT.drop('fare',axis='columns')
Data['fare']=label

# %%
Data
# Out:
#       pclass  survived  sex      age  sibsp  parch    cabin  embarked   body  \
# 0          1         1    0  29.0000      0      0       B5         0  177.0
# 1          1         1    1   0.9167      1      2  C22 C26         0  177.0
# 2          1         0    0   2.0000      1      2  C22 C26         0  177.0
# 3          1         0    1  30.0000      1      2  C22 C26         0  135.0
# 4          1         0    0  25.0000      1      2  C22 C26         0  177.0
# ...      ...       ...  ...      ...    ...    ...      ...       ...    ...
# 1304       3         0    0  14.5000      1      0      NaN         1  328.0
# 1305       3         0    0  30.0111      1      0      NaN         1  177.0
# 1306       3         0    1  26.5000      0      0      NaN         1  304.0
# 1307       3         0    1  27.0000      0      0      NaN         1  177.0
# 1308       3         0    1  29.0000      0      0      NaN         0  177.0
#
#       fare
# 0      273
# 1      270
# ...

# %%
dfT['cabin'].fillna(40, inplace=True)
dfT.cabin
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304         40
# 1305         40
# 1306         40
# 1307         40
# 1308         40
# Name: cabin, Length: 1309, dtype: object

# %%
dfT
# Out:
#       pclass  survived  sex      age  sibsp  parch      fare    cabin  \
# 0          1         1    0  29.0000      0      0  211.3375       B5
# 1          1         1    1   0.9167      1      2  151.5500  C22 C26
# 2          1         0    0   2.0000      1      2  151.5500  C22 C26
# 3          1         0    1  30.0000      1      2  151.5500  C22 C26
# 4          1         0    0  25.0000      1      2  151.5500  C22 C26
# ...      ...       ...  ...      ...    ...    ...       ...      ...
# 1304       3         0    0  14.5000      1      0   14.4542       40
# 1305       3         0    0  30.0111      1      0   14.4542       40
# 1306       3         0    1  26.5000      0      0    7.2250       40
# 1307       3         0    1  27.0000      0      0    7.2250       40
# 1308       3         0    1  29.0000      0      0    7.8750       40
#
#       embarked   body
# 0            0  177.0
# 1            0  177.0
# 2            0  177.0
# 3            0  135.0
# ...

# %%
print(dfT.columns)
# Out:
# Index(['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'fare', 'cabin',
#        'embarked', 'body'],
#       dtype='object')

# %%
X=dfT[['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch','fare', 'embarked']]

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
scaler.mean_
# Out:
# array([ 2.29488159,  0.38197097,  0.64400306, 29.90724675,  0.49885409,
#         0.38502674, 33.29547928,  0.39877769])

# %%
scaler.transform(X)
# Out:
# array([[-1.54609786,  1.27200629, -1.34499549, ..., -0.4449995 ,
#          3.44116502, -0.60334283],
#        [-1.54609786,  1.27200629,  0.74349692, ...,  1.86652569,
#          2.28560268, -0.60334283],
#        [-1.54609786, -0.78615963, -1.34499549, ...,  1.86652569,
#          2.28560268, -0.60334283],
#        ...,
#        [ 0.84191642, -0.78615963,  0.74349692, ..., -0.4449995 ,
#         -0.50388566,  0.90963756],
#        [ 0.84191642, -0.78615963,  0.74349692, ..., -0.4449995 ,
#         -0.50388566,  0.90963756],
#        [ 0.84191642, -0.78615963,  0.74349692, ..., -0.4449995 ,
#         -0.49132258, -0.60334283]])

# %%
scaler.get_params(deep=True)
# Out:
# {'copy': True, 'with_mean': True, 'with_std': True}

# %%
scaler.inverse_transform(X)
# Out:
# array([[3.13239752e+00, 8.67840447e-01, 6.44003056e-01, ...,
#         3.85026738e-01, 1.09676608e+04, 3.98777693e-01],
#        [3.13239752e+00, 8.67840447e-01, 1.12281734e+00, ...,
#         2.11548592e+00, 7.87432260e+03, 3.98777693e-01],
#        [3.13239752e+00, 3.81970970e-01, 6.44003056e-01, ...,
#         2.11548592e+00, 7.87432260e+03, 3.98777693e-01],
#        ...,
#        [4.80742938e+00, 3.81970970e-01, 1.12281734e+00, ...,
#         3.85026738e-01, 4.07108880e+02, 1.05972479e+00],
#        [4.80742938e+00, 3.81970970e-01, 1.12281734e+00, ...,
#         3.85026738e-01, 4.07108880e+02, 1.05972479e+00],
#        [4.80742938e+00, 3.81970970e-01, 1.12281734e+00, ...,
#         3.85026738e-01, 4.40739152e+02, 3.98777693e-01]])

# %%
scaler.partial_fit(X)
# Out:
# StandardScaler()

# %%
scaler.set_params()
# Out:
# StandardScaler()

# %%
scaler.transform(X)
# Out:
# array([[-1.54609786,  1.27200629, -1.34499549, ..., -0.4449995 ,
#          3.44116502, -0.60334283],
#        [-1.54609786,  1.27200629,  0.74349692, ...,  1.86652569,
#          2.28560268, -0.60334283],
#        [-1.54609786, -0.78615963, -1.34499549, ...,  1.86652569,
#          2.28560268, -0.60334283],
#        ...,
#        [ 0.84191642, -0.78615963,  0.74349692, ..., -0.4449995 ,
#         -0.50388566,  0.90963756],
#        [ 0.84191642, -0.78615963,  0.74349692, ..., -0.4449995 ,
#         -0.50388566,  0.90963756],
#        [ 0.84191642, -0.78615963,  0.74349692, ..., -0.4449995 ,
#         -0.49132258, -0.60334283]])

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()

# %%
normalizer.get_params(deep=True)
# Out:
# {'copy': True, 'norm': 'l2'}

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
minmax_data = scaler.fit_transform(dfT[['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch','fare', 'embarked']])
minmax_data
# Out:
# array([[0.        , 1.        , 0.        , ..., 0.        , 0.41250333,
#         0.        ],
#        [0.        , 1.        , 1.        , ..., 0.22222222, 0.2958059 ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.22222222, 0.2958059 ,
#         0.        ],
#        ...,
#        [1.        , 0.        , 1.        , ..., 0.        , 0.01410226,
#         0.33333333],
#        [1.        , 0.        , 1.        , ..., 0.        , 0.01410226,
#         0.33333333],
#        [1.        , 0.        , 1.        , ..., 0.        , 0.01537098,
#         0.        ]])

# %%
print(scaler.fit(X))
# Out:
# MinMaxScaler()

# %%
print(scaler.transform(X))
# Out:
# [[0.         1.         0.         ... 0.         0.41250333 0.        ]
#  [0.         1.         1.         ... 0.22222222 0.2958059  0.        ]
#  [0.         0.         0.         ... 0.22222222 0.2958059  0.        ]
#  ...
#  [1.         0.         1.         ... 0.         0.01410226 0.33333333]
#  [1.         0.         1.         ... 0.         0.01410226 0.33333333]
#  [1.         0.         1.         ... 0.         0.01537098 0.        ]]

# %%
print(scaler.inverse_transform(X))
# Out:
# [[3.00000000e+00 1.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   1.08274372e+05 0.00000000e+00]
#  [3.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.80000000e+01
#   7.76434903e+04 0.00000000e+00]
#  [3.00000000e+00 0.00000000e+00 0.00000000e+00 ... 1.80000000e+01
#   7.76434903e+04 0.00000000e+00]
#  ...
#  [7.00000000e+00 0.00000000e+00 1.00000000e+00 ... 0.00000000e+00
#   3.70157847e+03 3.00000000e+00]
#  [7.00000000e+00 0.00000000e+00 1.00000000e+00 ... 0.00000000e+00
#   3.70157847e+03 3.00000000e+00]
#  [7.00000000e+00 0.00000000e+00 1.00000000e+00 ... 0.00000000e+00
#   4.03459245e+03 0.00000000e+00]]

# %%
print(scaler.partial_fit(X))
# Out:
# MinMaxScaler()

# %%
scaler.transform(X)
# Out:
# array([[0.        , 1.        , 0.        , ..., 0.        , 0.41250333,
#         0.        ],
#        [0.        , 1.        , 1.        , ..., 0.22222222, 0.2958059 ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.22222222, 0.2958059 ,
#         0.        ],
#        ...,
#        [1.        , 0.        , 1.        , ..., 0.        , 0.01410226,
#         0.33333333],
#        [1.        , 0.        , 1.        , ..., 0.        , 0.01410226,
#         0.33333333],
#        [1.        , 0.        , 1.        , ..., 0.        , 0.01537098,
#         0.        ]])

# %%
scaler_data =scaler.fit_transform(dfT[['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch','fare', 'embarked']])
scaler_data
# Out:
# array([[0.        , 1.        , 0.        , ..., 0.        , 0.41250333,
#         0.        ],
#        [0.        , 1.        , 1.        , ..., 0.22222222, 0.2958059 ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.22222222, 0.2958059 ,
#         0.        ],
#        ...,
#        [1.        , 0.        , 1.        , ..., 0.        , 0.01410226,
#         0.33333333],
#        [1.        , 0.        , 1.        , ..., 0.        , 0.01410226,
#         0.33333333],
#        [1.        , 0.        , 1.        , ..., 0.        , 0.01537098,
#         0.        ]])

# %%
X
# Out:
#       pclass  survived  sex      age  sibsp  parch      fare  embarked
# 0          1         1    0  29.0000      0      0  211.3375         0
# 1          1         1    1   0.9167      1      2  151.5500         0
# 2          1         0    0   2.0000      1      2  151.5500         0
# 3          1         0    1  30.0000      1      2  151.5500         0
# 4          1         0    0  25.0000      1      2  151.5500         0
# ...      ...       ...  ...      ...    ...    ...       ...       ...
# 1304       3         0    0  14.5000      1      0   14.4542         1
# 1305       3         0    0  30.0111      1      0   14.4542         1
# 1306       3         0    1  26.5000      0      0    7.2250         1
# 1307       3         0    1  27.0000      0      0    7.2250         1
# 1308       3         0    1  29.0000      0      0    7.8750         0
#
# [1309 rows x 8 columns]

# %%
from sklearn import preprocessing 
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
data_MinMax=minmax.fit_transform(X)
print(data_MinMax)
# Out:
# [[0.         1.         0.         ... 0.         0.41250333 0.        ]
#  [0.         1.         1.         ... 0.22222222 0.2958059  0.        ]
#  [0.         0.         0.         ... 0.22222222 0.2958059  0.        ]
#  ...
#  [1.         0.         1.         ... 0.         0.01410226 0.33333333]
#  [1.         0.         1.         ... 0.         0.01410226 0.33333333]
#  [1.         0.         1.         ... 0.         0.01537098 0.        ]]

# %%
X
# Out:
#       pclass  survived  sex      age  sibsp  parch      fare  embarked
# 0          1         1    0  29.0000      0      0  211.3375         0
# 1          1         1    1   0.9167      1      2  151.5500         0
# 2          1         0    0   2.0000      1      2  151.5500         0
# 3          1         0    1  30.0000      1      2  151.5500         0
# 4          1         0    0  25.0000      1      2  151.5500         0
# ...      ...       ...  ...      ...    ...    ...       ...       ...
# 1304       3         0    0  14.5000      1      0   14.4542         1
# 1305       3         0    0  30.0111      1      0   14.4542         1
# 1306       3         0    1  26.5000      0      0    7.2250         1
# 1307       3         0    1  27.0000      0      0    7.2250         1
# 1308       3         0    1  29.0000      0      0    7.8750         0
#
# [1309 rows x 8 columns]

# %%
X1=dfT[['pclass', 'survived', 'sex',  'sibsp', 'parch', 'embarked']]

# %%
#classe pour l'ACP
from sklearn.decomposition import PCA
#instanciation
acp = PCA(svd_solver='full')
print(acp)
# Out:
# PCA(svd_solver='full')

# %%
pca = PCA(n_components=4)
pca.fit(X1)
print(pca.explained_variance_)
print(pca.explained_variance_ratio_)
# Out:
# [1.31080714 0.75074051 0.5463965  0.4570338 ]
# [0.38114952 0.21829633 0.15887827 0.13289385]

# %%
import numpy as np
import pandas as pd
dfrecap = pd.DataFrame(
 {
 "Valeur propre" : np.round(pca.explained_variance_),
 "% variance expliquée" : np.round(pca.explained_variance_ratio_ * 100),
 "% cum. var. expliquée" : np.round(np.cumsum(pca.explained_variance_ratio_) * 100)
 },
 index = ['Dim 1', 'Dim 2', 'Dim 3', 'Dim 4']
)
dfrecap
# Out:
#        Valeur propre  % variance expliquée  % cum. var. expliquée
# Dim 1            1.0                  38.0                   38.0
# Dim 2            1.0                  22.0                   60.0
# Dim 3            1.0                  16.0                   76.0
# Dim 4            0.0                  13.0                   89.0

# %%
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import numpy as np
import pandas as pd
#ajouter un cercle
#cercle = plt.Circle((0,0),1,color='blue',fill=False)
#ax.add_artist(cercle)
#affichage
#plt.show()

# %%
#cercle = plt.Circle((0,0),1,color='blue',fill=False)
cercle1 = plt.Circle((0, 0), 0.2, color='r')
cercle2= plt.Circle((0.5, 0.5), 0.2, color='y')
cercle3 = plt.Circle((1, 1), 0.2, color='m', clip_on=False)

fig, ax = plt.subplots() 

fig = plt.gcf()
ax = fig.gca()
ax.add_artist(cercle1)
ax.add_artist(cercle2)
ax.add_artist(cercle3)
fig.savefig('plotcircles.png')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
labels = ['Female', 'Male']
size = [112, 88]
colors = ['red', 'orange']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (7, 7)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title(' Representing the Gender')
plt.axis('off')
plt.legend()
plt.show()

# %%
sns.pairplot(dfT)

# %%
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import numpy as np
import pandas as pd

def display_circles(pcs, n_comp, pca, axis_ranks, labels=None, label_rotation=0, lims=None):
    for d1, d2 in axis_ranks: # On affiche les 3 premiers plans factoriels, donc les 6 premières composantes
        if d2 < n_comp:

            # initialisation de la figure
            fig, ax = plt.subplots(figsize=(7,6))

            # détermination des limites du graphique
            if lims is not None :
                xmin, xmax, ymin, ymax = lims
            elif pcs.shape[1] < 30 :
                xmin, xmax, ymin, ymax = -1, 1, -1, 1
            else :
                xmin, xmax, ymin, ymax = min(pcs[d1,:]), max(pcs[d1,:]), min(pcs[d2,:]), max(pcs[d2,:])

            # affichage des flèches
            # s'il y a plus de 30 flèches, on n'affiche pas le triangle à leur extrémité
            if pcs.shape[1] < 30 :
                plt.quiver(np.zeros(pcs.shape[1]), np.zeros(pcs.shape[1]),
                   pcs[d1,:], pcs[d2,:], 
                   angles='xy', scale_units='xy', scale=1, color="grey")
                # (voir la doc : https://matplotlib.org/api/_as_gen/matplotlib.pyplot.quiver.html)
            else:
                lines = [[[0,0],[x,y]] for x,y in pcs[[d1,d2]].T]
                ax.add_collection(LineCollection(lines, axes=ax, alpha=.1, color='black'))
            
            # affichage des noms des variables  
            if labels is not None:  
                for i,(x, y) in enumerate(pcs[[d1,d2]].T):
                    if x >= xmin and x <= xmax and y >= ymin and y <= ymax :
                        plt.text(x, y, labels[i], fontsize='14', ha='center', va='center', rotation=label_rotation, color="blue", alpha=0.5)
            
            # affichage du cercle
            circle = plt.Circle((0,0), 1, facecolor='none', edgecolor='b')
            plt.gca().add_artist(circle)

            # définition des limites du graphique
            plt.xlim(xmin, xmax)
            plt.ylim(ymin, ymax)
        
            # affichage des lignes horizontales et verticales
            plt.plot([-1, 1], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-1, 1], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
            plt.ylabel('F{} ({}%)'.format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

            plt.title("Cercle des corrélations (F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)
        
def display_factorial_planes(X_projected, n_comp, pca, axis_ranks, labels=None, alpha=1, illustrative_var=None):
    for d1,d2 in axis_ranks:
        if d2 < n_comp:
 
            # initialisation de la figure       
            fig = plt.figure(figsize=(7,6))
        
            # affichage des points
            if illustrative_var is None:
                plt.scatter(X_projected[:, d1], X_projected[:, d2], alpha=alpha)
            else:
                illustrative_var = np.array(illustrative_var)
                for value in np.unique(illustrative_var):
                    selected = np.where(illustrative_var == value)
                    plt.scatter(X_projected[selected, d1], X_projected[selected, d2], alpha=alpha, label=value)
                plt.legend()

            # affichage des labels des points
            if labels is not None:
                for i,(x,y) in enumerate(X_projected[:,[d1,d2]]):
                    plt.text(x, y, labels[i],
                              fontsize='14', ha='center',va='center') 
                
            # détermination des limites du graphique
            boundary = np.max(np.abs(X_projected[:, [d1,d2]])) * 1.1
            plt.xlim([-boundary,boundary])
            plt.ylim([-boundary,boundary])
        
            # affichage des lignes horizontales et verticales
            plt.plot([-100, 100], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-100, 100], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
            plt.ylabel('F{} ({}%)'.format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

            plt.title("Projection des individus (sur F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)

def display_scree_plot(pca):
    scree = pca.explained_variance_ratio_*100
    plt.bar(np.arange(len(scree))+1, scree)
    plt.plot(np.arange(len(scree))+1, scree.cumsum(),c="red",marker='o')
    plt.xlabel("rang de l'axe d'inertie")
    plt.ylabel("pourcentage d'inertie")
    plt.title("Eboulis des valeurs propres")
    plt.show(block=False)

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
from sklearn.decomposition import PCA
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
 

 
n_components = 4
 
# Do the PCA.
pca = PCA(n_components=n_components)
reduced = pca.fit_transform(df[['sepal_length', 'sepal_width',
                                'petal_length', 'petal_width']])

# Append the principle components for each entry to the dataframe
for i in range(0, n_components):
    df['PC' + str(i + 1)] = reduced[:, i]

display(df.head())

# Do a scree plot
ind = np.arange(0, n_components)
(fig, ax) = plt.subplots(figsize=(8, 6))
sns.pointplot(x=ind, y=pca.explained_variance_ratio_)
ax.set_title('Scree plot')
ax.set_xticks(ind)
ax.set_xticklabels(ind)
ax.set_xlabel('Component Number')
ax.set_ylabel('Explained Variance')
plt.show()

# Show the points in terms of the first two PCs
g = sns.lmplot('PC1',
               'PC2',
               hue='species',data=df,
               fit_reg=False,
               scatter=True,
               size=7)

plt.show()

# Plot a variable factor map for the first two dimensions.
(fig, ax) = plt.subplots(figsize=(8, 8))
for i in range(0, pca.components_.shape[1]):
    ax.arrow(0,
             0,  # Start the arrow at the origin
             pca.components_[0, i],  #0 for PC1
             pca.components_[1, i],  #1 for PC2
             head_width=0.1,
             head_length=0.1)

    plt.text(pca.components_[0, i] + 0.05,
             pca.components_[1, i] + 0.05,
             df.columns.values[i])


an = np.linspace(0, 2 * np.pi, 100)
plt.plot(np.cos(an), np.sin(an))  # Add a unit circle for scale
plt.axis('equal')
ax.set_title('Variable factor map')
plt.show()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species       PC1  \
# 0           5.1          3.5           1.4          0.2  setosa -2.684126
# 1           4.9          3.0           1.4          0.2  setosa -2.714142
# 2           4.7          3.2           1.3          0.2  setosa -2.888991
# 3           4.6          3.1           1.5          0.2  setosa -2.745343
# 4           5.0          3.6           1.4          0.2  setosa -2.728717
#
#         PC2       PC3       PC4
# 0  0.319397 -0.027915 -0.002262
# 1 -0.177001 -0.210464 -0.099027
# 2 -0.144949  0.017900 -0.019968
# 3 -0.318299  0.031559  0.075576
# 4  0.326755  0.090079  0.061259
# D:\DM\DV\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
